# %%
#print Statement 
print ("HOPE AI")
# Out:
# HOPE AI

# %%
#Buy inputs
institute_name=input("Enter your institute name? :")
# Out:
# Enter your institute name? : HOPE AI

# %%
#Buy inputs

stu_name=input("Enter your name: ")
stu_age=int(input("Enter your age: "))
stu_school=input("Enter your school name: ")
stu_degree=input("Enter your degree: ")
# Out:
# Enter your name:  Nandhini
# Enter your age:  36
# Enter your school name:  Girls School Ranganathapuram
# Enter your degree:  Bsc CT

# %%
#Addition , #subtraction 
a= 43
b= 34
add = a+b
sub = a-b 
print("a=",a,"\nb=",b,"\nadd =",add)
print("\na=",a,"\nb=",b,"\nSub =",sub)
# Out:
# a= 43
# b= 34
# add = 77
#
# a= 43
# b= 34
# Sub = 9

# %%
#Multiplication 
a= 63
b= 97
mul = a*b 
print("a=",a,"\nb=",b,"\nMul = ",mul)
# Out:
# a= 63
# b= 97
# Mul =  6111

# %%
#Division 
#Floor division
#modulo 
a= 76
b= 31 

float_div = a/b
floor_div = a//b 
modulo_div = a%b
print("a=",a,"\nb=",b,"\nFloat Div = ",float_div)
print("\na=",a,"\nb=",b,"\nFloor Div = ",floor_div)
print("\na=",a,"\nb=",b,"\nModulo = ",modulo_div)
# Out:
# a= 76
# b= 31
# Float Div =  2.4516129032258065
#
# a= 76
# b= 31
# Floor Div =  2
#
# a= 76
# b= 31
# Modulo =  14

# %%
#Power
a= 4
b= 4
power = a**b
print("a=",a,"\nb=",b,"\nPower = ",power)
# Out:
# a= 4
# b= 4
# Power =  256
